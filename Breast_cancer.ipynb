# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#read the fataset into pandas dataframe
df=pd.read_csv("C:\\Users\\hp\\OneDrive\\Desktop\\Breast_cancer_dataset.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int32
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.drop('Unnamed: 32', axis=1,inplace=True)

# %% [markdown]
# Used .info() to check structure of the dataset
# Identified null values and unique classes
# Dropped the unnecessary Unnamed: 32 column.

# %%
df.drop('id',axis=1,inplace=True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
##Encoding
df['diagnosis']=np.where(df['diagnosis'].str.contains("B"),0,1)

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# #  Data Visualization

# %%
#Countplot of the classes
sns.countplot(data=df, x='diagnosis')
plt.title('Diagnosis Distribution')
plt.show()

# %%
#Pie plot
#Percentage for Pie chart
percent=df['diagnosis'].value_counts(normalize=True)*100
     

##Plotting Pie chart
Classlabels=["Benign","Malignant"]
plt.figure(figsize=(12,7))
plt.pie(percent,labels=Classlabels,autopct='%1.1f%%')
plt.title("Pie Chart for Classes")
plt.show()

# %% [markdown]
# ##Plot density for all features
# plt.style.use('seaborn-v0_8')
# df.hist(bins=50,figsize=(20,15))
# plt.show()

# %%
#heatmap of all features
plt.figure(figsize=(18, 18))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix)
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
#Only showing top correlation features
top_corr = correlation_matrix['diagnosis'].abs().sort_values(ascending=False)[1:11]
print(top_corr)
top_features = top_corr.index
sns.heatmap(df[top_features].corr(), annot=True, cmap='coolwarm')
plt.title('Top 10 Features Correlation Heatmap')
plt.show()
# Out:
# concave points_worst    0.793566
# perimeter_worst         0.782914
# concave points_mean     0.776614
# radius_worst            0.776454
# perimeter_mean          0.742636
# area_worst              0.733825
# radius_mean             0.730029
# area_mean               0.708984
# concavity_mean          0.696360
# concavity_worst         0.659610
# Name: diagnosis, dtype: float64

# %%
#Analysing the mean value columns
features_to_plot = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'concavity_mean']

plt.figure(figsize=(15, 10))
for i, feature in enumerate(features_to_plot):
    plt.subplot(2, 3, i+1)
    sns.histplot(data=df, x=feature, hue='diagnosis', kde=True)
    plt.title(f'Distribution of {feature}')
plt.tight_layout()
plt.show()

# %%
#boxplot of selected features
plt.figure(figsize=(15, 10))
for i, feature in enumerate(features_to_plot):
    plt.subplot(2, 3, i+1)
    sns.boxplot(x='diagnosis', y=feature, data=df, palette='Set2')
    plt.title(f'Distribution of {feature}')
plt.tight_layout()
plt.show()

# %% [markdown]
# This shows the data has outliers

# %%
#Boxplot for outlier detection of all the features
plt.figure(figsize=(18, 10))
df.drop(columns='diagnosis').boxplot()
plt.xticks(rotation=90)
plt.title("Boxplot for Outlier Detection")
plt.show()

# %% [markdown]
# # Data Cleaning

# %%
#Displaying the skewness of the features
skew_vals = df.drop(columns='diagnosis').skew().sort_values()
print(skew_vals)
# Out:
# smoothness_worst           0.415426
# smoothness_mean            0.456324
# concave points_worst       0.492616
# texture_worst              0.498321
# texture_mean               0.650450
# symmetry_mean              0.725609
# radius_mean                0.942380
# perimeter_mean             0.990650
# radius_worst               1.103115
# perimeter_worst            1.128164
# concavity_worst            1.150237
# concave points_mean        1.171180
# compactness_mean           1.190123
# fractal_dimension_mean     1.304489
# concavity_mean             1.401180
# symmetry_worst             1.433928
# concave points_se          1.444678
# compactness_worst          1.473555
# area_mean                  1.645732
# texture_se                 1.646444
# fractal_dimension_worst    1.662579
# area_worst                 1.859373
# compactness_se             1.902221
# symmetry_se                2.195133
# smoothness_se              2.314450
# radius_se                  3.088612
# ...

# %%
#Remove outliers
def remove_outliers_iqr(data, columns):
    for col in columns:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Keep rows within bounds
        data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]
    return data

# Step 3: Apply outlier removal
df_cleaned = remove_outliers_iqr(df, df.columns)

# Step 4: Check new shape
print("Original Shape:", df.shape)
print("Cleaned Shape :", df_cleaned.shape)
# Out:
# Original Shape: (569, 31)
# Cleaned Shape : (277, 31)

# %%
print("Before removal:\n", df['diagnosis'].value_counts())
print("After removal:\n", df_cleaned['diagnosis'].value_counts())
# Out:
# Before removal:
#  diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64
# After removal:
#  diagnosis
# 0    255
# 1     22
# Name: count, dtype: int64

# %% [markdown]
# #The model after outlier removal has only 22 malignant examples way too few for good generalization.
# It's prefereable not to remove outliers in medical dataset. The model training can be done on original dataset

# %%
x=df.drop('diagnosis',axis=1)

# %%
y=df['diagnosis']

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=40)

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
# Step 5: Feature scaling
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# # Model Training

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report,ConfusionMatrixDisplay, \
                            precision_score, recall_score, f1_score, roc_auc_score,roc_curve

# %%
models={
    "Logisitic Regression":LogisticRegression(),
    "Decision Tree":DecisionTreeClassifier(),
    "Random Forest":RandomForestClassifier(),
    "Gradient Boost":GradientBoostingClassifier(),
    "KNeighbour":KNeighborsClassifier(n_neighbors=5,algorithm='auto'),
    "Adaboost":AdaBoostClassifier()
}

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score,confusion_matrix

def model_metric(models, x_train, y_train, x_test, y_test):
    for name, model in models.items():
        # Train model
        model.fit(x_train, y_train)

        # Predictions
        y_train_pred = model.predict(x_train)
        y_test_pred = model.predict(x_test)

        # Training performance
        model_train_accuracy = accuracy_score(y_train, y_train_pred)
        model_train_f1 = f1_score(y_train, y_train_pred, average='weighted')
        model_train_precision = precision_score(y_train, y_train_pred)
        model_train_recall = recall_score(y_train, y_train_pred)
        model_train_rocauc_score = roc_auc_score(y_train, y_train_pred)

        # Test performance
        model_test_accuracy = accuracy_score(y_test, y_test_pred)
        model_test_f1 = f1_score(y_test, y_test_pred, average='weighted')
        model_test_precision = precision_score(y_test, y_test_pred)
        model_test_recall = recall_score(y_test, y_test_pred)
        model_test_rocauc_score = roc_auc_score(y_test, y_test_pred)

        # Print results
        print(name)
        print('Model performance for Training set')
        print("- Accuracy: {:.4f}".format(model_train_accuracy))
        print('- F1 score: {:.4f}'.format(model_train_f1))
        print('- Precision: {:.4f}'.format(model_train_precision))
        print('- Recall: {:.4f}'.format(model_train_recall))
        print('- Roc Auc Score: {:.4f}'.format(model_train_rocauc_score))

        print('----------------------------------')

        print('Model performance for Test set')
        print('- Accuracy: {:.4f}'.format(model_test_accuracy))
        print('- F1 score: {:.4f}'.format(model_test_f1))
        print('- Precision: {:.4f}'.format(model_test_precision))
        print('- Recall: {:.4f}'.format(model_test_recall))
        print('- Roc Auc Score: {:.4f}'.format(model_test_rocauc_score))

        print('='*35)
        print('\n')
        # Confusion Matrix
        plt.figure(figsize=(3,3))
        cm = confusion_matrix(y_test, y_test_pred)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm)
        disp.plot(cmap="Blues", values_format='d')
        plt.title("Confusion Matrix")
        plt.show()
model_metric(models, x_train, y_train, x_test, y_test)
# Out:
# Logisitic Regression
# Model performance for Training set
# - Accuracy: 0.9883
# - F1 score: 0.9882
# - Precision: 0.9939
# - Recall: 0.9760
# - Roc Auc Score: 0.9861
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9720
# - F1 score: 0.9720
# - Precision: 0.9556
# - Recall: 0.9556
# - Roc Auc Score: 0.9676
# ...
# Decision Tree
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9580
# - F1 score: 0.9585
# - Precision: 0.8980
# - Recall: 0.9778
# - Roc Auc Score: 0.9634
# ...
# Random Forest
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9650
# - F1 score: 0.9651
# - Precision: 0.9348
# ...

# %% [markdown]
# KNN performed best with 97.9% test accuracy and minimal overfitting, followed closely by Logistic Regression and Gradient Boosting. Tree-based models showed signs of overfitting despite high accuracy.

# %% [markdown]
# # Hyperparameter Training

# %% [raw]
# #Logistic Regression

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
penaltty=['l1','l2','elasticnet']
c_values=[100, 10, 1.0, 0.1, 0.01]
solvers=['newton-cg','lbfgs','liblinear','sag','saga']

params_LR=dict(penalty=penaltty,C=c_values,solver=solvers)

# %%
param_grid_KNN = {
    "n_neighbors": range(3, 21),
    "weights": ["uniform", "distance"],
    "metric": ["euclidean", "manhattan", "minkowski"] }

# %%
gradientboost_params={"loss":['log_loss','deviance','exponential'],
                 "criterion":['friedman_mse','squared_error','mse'],
                 "min_samples_split":[2,8,15,20],
                 "n_estimators":[100,200,500],
                 "max_depth":[5,8,15,None,10]}

# %%
# Models list for Hyperparameter tuning
models = [
                   ("LR", LogisticRegression(), params_LR ),
    ("KNN",  KNeighborsClassifier(), param_grid_KNN),
    ("GradientBoost",GradientBoostingClassifier(),gradientboost_params)]

# %%
model_param = {}
for name, model, params in models:
    random = RandomizedSearchCV(estimator=model,
                                   param_distributions=params,
                                   n_iter=100,
                                   cv=3,
                                   verbose=2,
                                   n_jobs=-1)
    random.fit(x_train, y_train)
    model_param[name] = random.best_params_
# Out:
# Fitting 3 folds for each of 75 candidates, totalling 225 fits
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Fitting 3 folds for each of 100 candidates, totalling 300 fits

# %%
for model_name in model_param:
    print(f"----------- Best Params for {model_name} ---------")
    print(model_param[model_name])
# Out:
# ----------- Best Params for LR ---------
# {'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# ----------- Best Params for KNN ---------
# {'weights': 'uniform', 'n_neighbors': 3, 'metric': 'manhattan'}
# ----------- Best Params for GradientBoost ---------
# {'n_estimators': 500, 'min_samples_split': 20, 'max_depth': 5, 'loss': 'log_loss', 'criterion': 'friedman_mse'}

# %%
models_hyper={
    "Logisitic Regression":LogisticRegression(solver='liblinear', penalty= 'l2', C= 0.1),
    "Gradient Boost":GradientBoostingClassifier(n_estimators= 500, min_samples_split= 20, max_depth=5, loss= 'log_loss', criterion= 'friedman_mse'),
    "KNeighbour":KNeighborsClassifier(weights= 'uniform', n_neighbors= 3, metric= 'manhattan')
}

# %%
model_metric(models_hyper, x_train, y_train, x_test, y_test)
# Out:
# Logisitic Regression
# Model performance for Training set
# - Accuracy: 0.9836
# - F1 score: 0.9835
# - Precision: 0.9878
# - Recall: 0.9701
# - Roc Auc Score: 0.9812
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9720
# - F1 score: 0.9720
# - Precision: 0.9556
# - Recall: 0.9556
# - Roc Auc Score: 0.9676
# ...
#
#
# Gradient Boost
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9580
# - F1 score: 0.9583
# - Precision: 0.9149
# - Recall: 0.9556
# - Roc Auc Score: 0.9574
# ...
#
#
# KNeighbour
# Model performance for Training set
# - Accuracy: 0.9859
# - F1 score: 0.9859
# - Precision: 1.0000
# - Recall: 0.9641
# - Roc Auc Score: 0.9820
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9860
# - F1 score: 0.9860
# - Precision: 0.9778
# ...

# %% [markdown]
# The hyperparameter tuning process, which included RandomizedCv on Logistic Regression, Gradient Boosting, and K-Nearest Neighbors (KNN), concluded with KNN as the top-performing model. *KNN achieved the highest metrics on the test set, including an accuracy and F1-score of 98.6% and an ROC AUC of 98.38%*. Logistic Regression proved to be a reliable and stable baseline, demonstrating balanced performance with minimal overfitting. In contrast, Gradient Boosting performed perfectly on the training data but showed clear signs of overfitting with its comparatively lower test set scores.

# %% [markdown]
# **KNN** is the most effective model for this particular dataset
